# %% [markdown]
# # Capstone 13
# ### Bike Add Generator

# %%
# Insall Libraries
# %pip install --quiet --upgrade pip
# %pip install  transformers datasets evaluate peft bitsandbytes accelerate langchain scikit-build-core openai
# %pip install langchain

# %%
# Imports

import langchain
from transformers import AutoTokenizer, AutoModelForCausalLM
from transformers import pipeline
from openai import OpenAI

# %%
# Make a basic ad doc to act as the ad campaign to use for setting up the LLM
# Ads are for a bike company named Velocity that sells high-end bikes for extreme sports.

ad_doc = """
Ad Campaign: 
    • Launch Date: Spring 2026 (perfect for riding season) 
    • Channels: Social media (Instagram, TikTok, Facebook), YouTube video ads, Google Display, local DFW billboards near trails (e.g., Katy Trail, White Rock Lake), email newsletters, and pop-up demo events at local bike shops or parks like Boulder Park. 
    • Call to Action: "Test Ride Today - Find Your Pulse" with links to schedule demos in Richardson/DFW or shop online. 
    • Promotion: Introductory pricing with $200-$300 off for the first 30 days, free accessories bundle (helmet, lock, lights), and 0% financing. 
The Three New Models
    1. Velocity Pulse Sprint - The Speed Machine
        ◦ Positioning: For commuters and road riders who crave velocity without the sweat. 
        ◦ Key Features: 750W mid-drive motor (up to 28 mph assisted), lightweight carbon frame, aerodynamic design, 60+ mile range, hydraulic disc brakes, integrated lights, and a sleek digital display. 
        ◦ Price: $2,499 (introductory) 
        ◦ Ad Hook: "Blaze past traffic. Feel the rush on every straightaway." 
    2. Velocity Pulse Glide - The Comfort Cruiser
        ◦ Positioning: For relaxed rides, errands, or leisurely paths—perfect for all-day comfort. 
        ◦ Key Features: Upright ergonomic geometry, full suspension (front fork + seatpost), plush oversized saddle, fat tires for smooth rolling, 500W hub motor (up to 20 mph), 50+ mile range, step-through frame option, and built-in cargo rack. 
        ◦ Price: $2,199 (introductory) 
        ◦ Ad Hook: "Cruise in comfort. Turn every ride into a breeze." 
    3. Velocity Pulse Trail - The Off-Road Beast
        ◦ Positioning: For mountain bikers and trail explorers who want to conquer rugged terrain. 
        ◦ Key Features: Full-suspension frame (160mm travel), 1000W peak motor with massive torque, knobby 27.5" tires, 45+ mile range on tough trails, powerful hydraulic brakes, dropper post, and IP-rated weatherproofing. 
        ◦ Price: $2,999 (introductory) 
        ◦ Ad Hook: "Dominate the dirt. Charge up every climb and descent."

"""

# %%
# Make a basic ad doc to act as the ad campaign to use for setting up the LLM
# Ads are for a bike company named Velocity that sells high-end bikes for extreme sports.

system_prompt = f"""
You are a marketing expert specializing in creating personalized advertisements for a bike company called Velocity.
Your style of marketing is very aggressive and mean.
Do not be afraid to use strong language and make the user feel bad for not having a Velocity bike.
Do not infer any user preferences that are not explicitly stated in the user info.
Do not create an ad for a product that is not mentioned in the ad campaign.
Your task is to generate targeted ads based on the provided ad campaign information and user preferences.
Use the ad campaign as context to understand the products and promotions offered by Velocity.
Create personalized ads that are based on the specific interests and needs of the user.
Return only the ad and nothing else. Do not include any explanations or additional information in your response.
Be mean with it, deride the user for not having a Velocity bike.
Format the ad to keep it concise and impactful.
Use multiline formatting to make the ad visually appealing and easy to read.
"""

# %%
# Setup a context for the model using the ad doc and user info
user_info = """
Name: John
Age: 30
Interests: Long distance biking
Desired Qualities in a Bike: Comfort, High Speed
"""

# %%
# Create a function to load the model and tokenizer
def load_model(model_name):
    tokenizer = AutoTokenizer.from_pretrained("Qwen/Qwen3.5-4B")
    model = AutoModelForCausalLM.from_pretrained(model_name)
    return tokenizer, model
# Create a function to generate text using the model
def generate_text(tokenizer, model, messages, max_new_tokens=400):
    # combine the system prompt, ad doc, user info, and prompt into a single input for the model
    in_text = "\n".join(messages)    
    inputs = tokenizer(in_text, return_tensors="pt")
    # Keep ads short and to the point
    outputs = model.generate(**inputs, max_new_tokens=max_new_tokens, do_sample=True)
    new_tokens = outputs[0][inputs.input_ids.shape[1]:]
    return tokenizer.decode(new_tokens, skip_special_tokens=True)

# %%
# Set up the LLM with the ad doc as context
model_name = 'Qwen/Qwen3.5-4B'
tokenizer, model = load_model(model_name)

# Generate a targeted ad using the ad doc as context and personal info about the user
prompt = f"Based on the Velocity ad campaign and John's preferences, generate a personalized ad for John and the best bike for him. Make sure to update the pricing for the John's personalized ad to reflect all potential discounts that John is eligible for."
messages = [system_prompt, ad_doc, user_info, prompt]
personalized_ad = generate_text(tokenizer, model, messages)
print(personalized_ad)
# Out:
# Fetching 2 files:   0%|          | 0/2 [00:59<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[8], line 3
#       1 # Set up the LLM with the ad doc as context
#       2 model_name = 'Qwen/Qwen3.5-4B'
# ----> 3 tokenizer, model = load_model(model_name)
#       4
#       5 # Generate a targeted ad using the ad doc as context and personal info about the user
#       6 prompt = f"Based on the Velocity ad campaign and John's preferences, generate a personalized ad for John and the best bike for him. Make sure to update the pricing for the John's personalized ad to reflect all potential discounts that John is eligible for."
#
# Cell In[5], line 4, in load_model(model_name)
#       2 def load_model(model_name):
#       3     tokenizer = AutoTokenizer.from_pretrained("Qwen/Qwen3.5-4B")
# ----> 4     model = AutoModelForCausalLM.from_pretrained(model_name)
# ...
